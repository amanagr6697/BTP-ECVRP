# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# # S = 0.002  
# # thresholds = [50, 100, 150, 200]
# # multipliers = [1.0, 1.19, 1.29, 1.39, 1.49]
# # ranges=4
# # t_base = {}

# # for i, j, k in A:
# #     avg_value = c[i,j]
# #     if(c[i,j]<thresholds[0]):
# #         for k in K:
# #                 t_base[i, j, k] = mxWeightAllowed[k] *S* multipliers[0]*c[i,j]
# #     elif(c[i,j]<=200):
# #          for x in range(0,ranges-1):
# #               if(c[i,j]>=thresholds[x] and c[i,j]<=thresholds[x+1]):
# #                            for k in K:
# #                                t_base[i, j, k] = mxWeightAllowed[k] *S* multipliers[x+1]*c[i,j]
# #     else:
# #          for k in K:
# #                 t_base[i, j, k] = mxWeightAllowed[k] *S* multipliers[ranges-1]*c[i,j]



# demandWeight = {i: rnd.uniform(1, 10) for i in All}
# mxBatteryLevels = [0]*(mxVehicles+1)
# fastChargingTimePerUnitOfCharge = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# slowChargingTimePerUnitOfCharge= [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# mediumChargingTimePerUnitOfCharge= [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# batterySwappingTime = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# costPerUnitChargeOfFast= [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# costPerUnitChargeOfMedium= [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# costPerUnitChargeOfSlow= [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# batterySwappingCost = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# fastTimeChargers = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# mediumTimeChargers = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# slowTimeChargers = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# batteryStatNum = [0]*(mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)
# mxCostAllowed = [0]*(mxVehicles+1)
# speedOfVehicles = [0]*(mxVehicles+1)
# weightFactorFoSpeed = [0]*(mxVehicles+1)
# mxWeightAllowed = [0]*(mxVehicles+1)



# # Vehicle charging min and max constraints
# minChargeValue = 30000
# maxChargeValue = 50000

# # Time constraints for fast 
# minFastTimeValue = 2.0
# maxFastTimeValue = 3.0

# #Time constraint for medium
# minMediumTimeValue = 4.0
# maxMediumTimeValue = 5.0

# #TIme constraint for slow
# minSlowTimeValue = 7.0
# maxSlowTImeValue = 8.0

# #Time constraint for swapping battery
# minBatSwapTime = 0.5
# maxBatSwapTIme = 0.8

# #Cost constraint for fast charging
# minFastChargerCost = 300.0
# maxFastChargerCost = 400.0

# #Cost constraint for medium charging
# minMediumChargerCost = 200.0
# maxMediumChargerCost = 300.0

# #Cost constraint for slow charging
# minSlowChargerCost = 100.0
# maxSlowChargerCost = 200.0

# #Battery swap cost 
# minBatterySwapCost = 550.0
# maxBatterySwapCost = 650.0

# #Max allowed vehicle cost
# minVehicleCostLimit = 30000
# maxVehicleCostLimit = 50000

# lb = 14
# ub = 20
# for i in range(1,k+1):
#       mxBatteryLevels[i] = rnd.uniform(minChargeValue, maxChargeValue)
#       mxWeightAllowed[i] = rnd.uniform(lb,ub);

# for i in range(mxCustomers+2, mxCustomers+1+num_of_copies*mxChargingStations+1):
#       fastChargingTimePerUnitOfCharge[i] = rnd.uniform(minFastTimeValue,maxFastTimeValue)
#       mediumChargingTimePerUnitOfCharge[i] = rnd.uniform(minMediumTimeValue, maxMediumTimeValue)
#       slowChargingTimePerUnitOfCharge[i] = rnd.uniform(minSlowTimeValue, maxSlowTImeValue)
#       costPerUnitChargeOfFast[i] = rnd.uniform(minFastChargerCost, maxFastChargerCost)
#       costPerUnitChargeOfMedium[i] = rnd.uniform(minMediumChargerCost, maxMediumChargerCost)
#       costPerUnitChargeOfSlow[i] = rnd.uniform(minSlowChargerCost, maxSlowChargerCost)
#       fastTimeChargers[i] = 1
#       slowTimeChargers[i] = 1
#       mediumTimeChargers[i] = 1

# for i in range(mxCustomers+1+num_of_copies*mxChargingStations+1,mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1):
#       batterySwappingTime[i] = rnd.uniform(minBatSwapTime, maxBatSwapTIme)
#       batterySwappingCost[i] = rnd.uniform(minBatterySwapCost,maxBatterySwapCost)
#       batteryStatNum[i] = 1

# demandWeight[0]=0
# for i in range(mxCustomers+1,mxCustomers+2+num_of_copies*(mxChargingStations+mxBatterySwappingStations)):
#     demandWeight.get(i,0) = 0

# for i in range(1,mxVehicles+1):
#       mxCostAllowed[i] = rnd.randint(minVehicleCostLimit,maxVehicleCostLimit)

# %%
import json

# Load JSON data from a file
with open('data.json', 'r') as file:
    json_data = json.load(file)

import json

# Load JSON data from a file
with open('data.json', 'r') as file:
    json_data = json.load(file)

# Extract location array
location = {i: {'latitude': location['latitude'], 'longitude': location['longitude']} for i, location in enumerate(json_data['location'])}

# Extract battery charging station array
batteryChargingStations = {i+1: {'latitude': station['latitude'], 'longitude': station['longitude']} for i, station in enumerate(json_data['batterychargingstation'])}

# Extract battery swapping station array
batterySwappingStations = {i+1: {'latitude': station['latitude'], 'longitude': station['longitude']} for i, station in enumerate(json_data['batteryswappingstation'])}

# Append location, battery charging stations, and battery swapping stations with increasing indexes
index = 0

latitude = {}
longitude = {}

for i in range(len(location) + len(batteryChargingStations) + len(batterySwappingStations)+1):
    if i <= len(location):
        latitude[index] = location[(i)%len(location)]['latitude']
        longitude[index] = location[(i)%len(location)]['longitude']
    elif i < len(location) + len(batteryChargingStations)+1:
        latitude[index] = location[i - len(location)]['latitude']
        longitude[index] = location[i - len(location)]['longitude']
    else:
        latitude[index] = location[i - len(location) - len(batteryChargingStations)]['latitude']
        longitude[index] = location[i - len(location) - len(batteryChargingStations)]['longitude']
    index += 1

# Extract demandWeight
demandWeight = {i: location.get("demandWeight", 0) for i, location in enumerate(json_data.get("location", []))}

# Extract other attributes
mxBatteryLevels = {i+1: vehicle.get("mxBatteryLevels", 0) for i, vehicle in enumerate(json_data.get("vehicle", []))}
mxCostAllowed = {i+1: vehicle.get("mxCostAllowed", 0) for i, vehicle in enumerate(json_data.get("vehicle", []))}
mxWeightAllowed = {i+1: vehicle.get("mxWeightAllowed", 0) for i, vehicle in enumerate(json_data.get("vehicle", []))}
speedOfVehicles = {i+1: vehicle.get("speedOfVehicles", 0) for i, vehicle in enumerate(json_data.get("vehicle", []))}
weightFactorForSpeed = {i+1: vehicle.get("weightFactorForSpeed", 0) for i, vehicle in enumerate(json_data.get("vehicle", []))}
weightFactorForDistance = {i+1: vehicle.get("weightFactorForDistance", 0) for i, vehicle in enumerate(json_data.get("vehicle", []))}

# Extract individual variables
fastChargingTimePerUnitOfCharge = json_data.get('fastChargingTimePerUnitOfCharge', 0)
mediumChargingTimePerUnitOfCharge = json_data.get('mediumChargingTimePerUnitOfCharge', 0)
slowChargingTimePerUnitOfCharge = json_data.get('slowChargingTimePerUnitOfCharge', 0)
batterySwappingCost = json_data.get('batterySwappingCost', 0)
batterySwappingTime = json_data.get('batterySwappingTime', 0)
mxVehicles = json_data.get('mxVehicles', 0)
mxCustomers = json_data.get('mxCustomers', 0)
dischargingConst = json_data.get('dischargingConst', 0)
temperature = json_data.get('temperature', 0)
scalingFactor = json_data.get('scalingFactor', 0)
parameter = json_data.get('parameter', 0)
fastTimeChargers = json_data.get('fastTimeChargers', 0)
mediumTimeChargers = json_data.get('mediumTimeChargers', 0)
slowTimeChargers = json_data.get('slowTimeChargers', 0)
batteriesAvailable = json_data.get('batteriesAvailable', 0)
costPerUnitChargeOfFast = json_data.get('costPerUnitChargeOfFast', 0)
costPerUnitChargeOfMedium = json_data.get('costPerUnitChargeOfMedium', 0)
costPerUnitChargeOfSlow = json_data.get('costPerUnitChargeOfSlow', 0)
mxBatteryChargingStations = json_data.get('mxBatteryChargingStations', 0)
mxBatterySwappingStations = json_data.get('mxBatterySwappingStations', 0)

# %%
print(mxCustomers)
# Out:
# 4

# %%
num_of_copies = 1
I = [i for i in range(1, mxCustomers+1)] #Number of nodes/locations
F = [i for i in range(mxCustomers+2,mxCustomers+1+num_of_copies*mxChargingStations+1)]
B = [i for i in range(mxCustomers+1+num_of_copies*mxChargingStations+1,mxCustomers+1+num_of_copies*mxChargingStations+num_of_copies*mxBatterySwappingStations+1)]
F_comb = F + B
All = I + F + B
F_depo = [0] + F + B
I_depo = [0] + All
I_dest = All + [mxCustomers+1]
I_depo_dest = All + [0] + [mxCustomers+1]
K = [i for i in range(1,mxVehicles+1)]
A = [(i, j, k) for i in I_depo for j in I_dest for k in K if i != j] 
dist = [(i, j) for i in I_depo for j in I_dest if i != j] 
total_with_vehicles = [(i,k) for i in I_depo_dest for k in K]
kthVehicleChargingAndSwapping = [(i,k) for i in F_comb for k in K]
#For auxTime
auxVariable = [(i,j,k) for i in I_depo for j in F if i!=j for k in K]
auxDiv = [(i,k) for i in I_dest for k in K]

# %%
print(I)
print(F)
print(B)
# Out:
# [1, 2, 3, 4]
# [6, 7, 8]
# [9, 10, 11]

# %%
c = {(i, j): np.hypot(latitude[i]-latitude[j], longitude[i]-longitude[j]) for i, j in dist} 

t_base = {}

for i, j, k in A:
      t_base[i,j,k] = c[i,j]/speedOfVehicles[k];

dischargingAdditive = dischargingConst * parameter + temperature * scalingFactor

# %%
print("latitude:")
for key, value in latitude.items():
    print(f"{key}: {value}")

print("longitude:")
for key, value in longitude.items():
    print(f"{key}: {value}")

print("\nBattery Charging Stations:")
for key, value in batteryChargingStations.items():
    print(f"{key}: {value}")

print("\nBattery Swapping Stations:")
for key, value in batterySwappingStations.items():
    print(f"{key}: {value}")

print("\nDemandWeight:")
for key, value in demandWeight.items():
    print(f"{key}: {value}")

print("\nmxBatteryLevels:")
for key, value in mxBatteryLevels.items():
    print(f"{key}: {value}")

print("\nmxCostAllowed:")
for key, value in mxCostAllowed.items():
    print(f"{key}: {value}")

print("\nmxWeightAllowed:")
for key, value in mxWeightAllowed.items():
    print(f"{key}: {value}")

print("\nspeedOfVehicles:")
for key, value in speedOfVehicles.items():
    print(f"{key}: {value}")

print("\nweightFactorForSpeed:")
for key, value in weightFactorForSpeed.items():
    print(f"{key}: {value}")

print("\nweightFactorForDistance:")
for key, value in weightFactorForDistance.items():
    print(f"{key}: {value}")

print(f"\nfastChargingTimePerUnitOfCharge: {fastChargingTimePerUnitOfCharge}")
print(f"mediumChargingTimePerUnitOfCharge: {mediumChargingTimePerUnitOfCharge}")
print(f"slowChargingTimePerUnitOfCharge: {slowChargingTimePerUnitOfCharge}")
print(f"batterySwappingCost: {batterySwappingCost}")
print(f"batterySwappingTime: {batterySwappingTime}")
print(f"mxVehicles: {mxVehicles}")
print(f"mxCustomers: {mxCustomers}")
print(f"dischargingConst: {dischargingConst}")
print(f"temperature: {temperature}")
print(f"scalingFactor: {scalingFactor}")
print(f"parameter: {parameter}")
print(f"fastTimeChargers: {fastTimeChargers}")
print(f"mediumTimeChargers: {mediumTimeChargers}")
print(f"slowTimeChargers: {slowTimeChargers}")
print(f"batteriesAvailable: {batteriesAvailable}")
print(f"costPerUnitChargeOfFast: {costPerUnitChargeOfFast}")
print(f"costPerUnitChargeOfMedium: {costPerUnitChargeOfMedium}")
print(f"costPerUnitChargeOfSlow: {costPerUnitChargeOfSlow}")
print(f"mxBatteryChargingStations: {mxBatteryChargingStations}")
print(f"mxBatterySwappingStations: {mxBatterySwappingStations}")
# Out:
# latitude:
# 0: 23
# 1: 20
# 2: 10
# 3: 15
# 4: 30
# 5: 23
# 6: 20
# 7: 10
# 8: 15
# 9: 20
# 10: 10
# 11: 15
# longitude:
# 0: 27
# 1: 15
# 2: 25
# 3: 10
# 4: 20
# 5: 27
# 6: 15
# 7: 25
# 8: 10
# 9: 15
# 10: 25
# 11: 10
#
# Battery Charging Stations:
# 1: {'latitude': 13, 'longitude': 12}
# 2: {'latitude': 8, 'longitude': 19}
# 3: {'latitude': 14, 'longitude': 18}
#
# Battery Swapping Stations:
# 1: {'latitude': 29, 'longitude': 13}
# 2: {'latitude': 15, 'longitude': 11}
# 3: {'latitude': 18, 'longitude': 7}
#
# DemandWeight:
# 0: 0
# 1: 15
# 2: 20
# 3: 20
# 4: 15
#
# mxBatteryLevels:
# 1: 500
# 2: 300
#
# mxCostAllowed:
# 1: 100
# 2: 100
#
# mxWeightAllowed:
# 1: 50
# 2: 50
#
# speedOfVehicles:
# 1: 100
# 2: 100
#
# weightFactorForSpeed:
# 1: 0.05
# 2: 0.05
#
# weightFactorForDistance:
# 1: 0.13
# 2: 0.13
#
# fastChargingTimePerUnitOfCharge: 0.005
# mediumChargingTimePerUnitOfCharge: 0.008
# slowChargingTimePerUnitOfCharge: 0.013
# batterySwappingCost: 30
# batterySwappingTime: 0.2
# ...

# %%
print(demandWeight)
print(mxBatteryLevels)
print(mxWeightAllowed)
print(batterySwappingTime)
print(batterySwappingCost)
print(batteriesAvailable)
print(fastChargingTimePerUnitOfCharge)
print(slowChargingTimePerUnitOfCharge)
print(mediumChargingTimePerUnitOfCharge)
print(costPerUnitChargeOfMedium)
print(costPerUnitChargeOfSlow)
print(costPerUnitChargeOfFast)
print(I_depo)
print(B)
print(I)
print(F)
print(B)
print(I_dest)
print(I_depo)
print(I)
print(F)
print(F_comb)
print(B)
print(auxVariable)
print(t_base)
print(t_base[0,1,2])
# Out:
# {0: 0, 1: 15, 2: 20, 3: 20, 4: 15}
# {1: 500, 2: 300}
# {1: 50, 2: 50}
# 0.2
# 30
# 3
# 0.005
# 0.013
# 0.008
# 1.4
# 0.9
# 3
# [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11]
# [9, 10, 11]
# [1, 2, 3, 4]
# [6, 7, 8]
# [9, 10, 11]
# [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 5]
# [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11]
# [1, 2, 3, 4]
# [6, 7, 8]
# [6, 7, 8, 9, 10, 11]
# [9, 10, 11]
# ...

# %%
from gurobipy import Model, GRB, quicksum

model = Model('ECVRP')
x = model.addVars(A, vtype=GRB.BINARY, name='x')
u = model.addVars(total_with_vehicles, vtype=GRB.CONTINUOUS,lb=0.0, name='u')
y = model.addVars(total_with_vehicles, vtype=GRB.CONTINUOUS,lb=0.0, name='y')
h = model.addVars(total_with_vehicles, vtype=GRB.CONTINUOUS, name='h')
fastCh = model.addVars(kthVehicleChargingAndSwapping, vtype = GRB.BINARY, name = "fast charging")
mediumCh = model.addVars(kthVehicleChargingAndSwapping, vtype = GRB.BINARY, name = "meidum charging")
slowCh = model.addVars(kthVehicleChargingAndSwapping, vtype = GRB.BINARY, name = "slow charging")
batterySwap = model.addVars(kthVehicleChargingAndSwapping, vtype = GRB.BINARY, name = "battery swapping")
auxTime = model.addVars(auxVariable, vtype = GRB.CONTINUOUS, name = "Auxillary variable for time")
auxCost = model.addVars(auxVariable, vtype = GRB.CONTINUOUS, name = "Auxillary variable for cost")
auxDivisor = model.addVars(auxDiv, vtype = GRB.CONTINUOUS, name = "Auxillary variable for divisor")

#Minimizing the maximum total time a vehicle takes
model.modelSense = GRB.MINIMIZE 
#Setting the objective function
model.setObjective(quicksum(x[i, j, k]*t_base[i,j,k]*auxDivisor[j,k] for i in I_depo for j in I_dest if i!=j for k in K) +  quicksum(auxTime[i,j,k]*(mxBatteryLevels[k] - y[j,k]) for i in I_depo for j in F if i!=j for k in K) + quicksum(x[i,j,k]*batterySwappingTime*batterySwap[j,k] for i in I_depo for j in B if i!=j for k in K))
model.addConstrs(((1+weightFactorForSpeed[k]*u[j,k])*(auxDivisor[j,k]))==1 for j in I_dest for k in K)
model.addConstrs((quicksum(x[i, j, k] for k in K for j in I_dest if i!=j) == 1 for i in I), name='outgoing')
model.addConstrs((quicksum(x[i, j, k] for k in K for j in I_dest if i!=j) <= 1 for i in F_comb), name='charging_outgoing')
model.addConstrs((quicksum(x[0, j, k] for j in All) <= 1 for k in K), name='charging_outgoing')
model.addConstrs((quicksum(x[i, j, k] for i in I_depo if i!=j)-quicksum(x[j,i,k] for i in I_dest if i!=j) == 0 for j in All for k in K), name='blockage')
model.addConstrs((u[j,k]<=u[i,k]-demandWeight.get(i,0)*x[i,j,k]+ mxWeightAllowed[k]*(1-x[i,j,k]) for i in I_depo for j in I_dest if i!=j for k in K), name='weight_transfer')
model.addConstrs(y[j,k]<=mxBatteryLevels[k] - h[i,k]*c[i,j]*x[i,j,k] for i in F for j in I_dest if i!=j for k in K)
model.addConstrs((u[0,k]<=mxWeightAllowed[k] for k in K), name='Specifying_constant_weight')
model.addConstrs((y[0,k]==mxBatteryLevels[k] for k in K), name='Specifying_constant_charge')
model.addConstrs(u[0,k]==quicksum(x[i,j,k]*demandWeight.get(j,0) for i in I_depo for j in I if i!=j) for k in K)
model.addConstrs(quicksum(auxCost[i, j, k] * (mxBatteryLevels[k] - y[j, k]) for j in F for i in I_depo if i != j) +quicksum(batterySwap[p, k] * batterySwappingCost for p in B for i in I_depo if i != p) <= mxCostAllowed[k] for k in K)
model.addConstrs((y[j,k]<=y[i,k]-h[i,k]*c[i,j]*x[i,j,k]+mxBatteryLevels[k]*(1-x[i,j,k]) for i in I for j in I_dest  if i!=j for k in K), name = 'charge_left')
model.addConstrs(h[i,k] == dischargingAdditive + u[i,k] / mxWeightAllowed[k] for i in I_depo_dest for k in K)
model.addConstrs(quicksum(fastCh[i,k] for k in K)<=fastTimeChargers for i in F)
model.addConstrs(quicksum(mediumCh[i,k] for k in K)<=mediumTimeChargers for i in F)
model.addConstrs(quicksum(slowCh[i,k] for k in K)<=slowTimeChargers for i in F)
model.addConstrs(quicksum(batterySwap[i,k] for k in K)<=batteriesAvailable for i in B)
model.addConstrs(auxTime[i,j,k]==x[i,j,k]*(fastCh[j,k]*fastChargingTimePerUnitOfCharge + slowCh[j,k]*slowChargingTimePerUnitOfCharge + mediumCh[j,k]*mediumChargingTimePerUnitOfCharge) for i in I_depo for j in F if i!=j for k in K)
model.addConstrs(auxCost[i,j,k]==x[i,j,k]*(fastCh[j,k]*costPerUnitChargeOfFast + slowCh[j,k]*costPerUnitChargeOfSlow + mediumCh[j,k]*costPerUnitChargeOfMedium) for i in I_depo for j in F if i!=j for k in K)
model.addConstrs((fastCh[i,k] + mediumCh[i,k] + slowCh[i,k])<=1 for i in F for k in K)
model.Params.MIPGap = 0.1
model.Params.TimeLimit = 200 # seconds
model.params.NonConvex = 2

model.optimize()
# Out:
# Set parameter MIPGap to value 0.1
# Set parameter TimeLimit to value 200
# Set parameter NonConvex to value 2
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-6500U CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 302 rows, 484 columns and 1462 nonzeros
# Model fingerprint: 0xdf679c28
# Model has 304 quadratic objective terms
# Model has 284 quadratic constraints
# Variable types: 214 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+01]
#   QMatrix range    [5e-03, 2e+01]
#   QLMatrix range   [1e+00, 5e+02]
#   Objective range  [3e+02, 5e+02]
#   QObjective range [1e-01, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#   QRHS range       [1e+00, 5e+02]
# Presolve added 402 rows and 0 columns
# Presolve removed 0 rows and 50 columns
# Presolve time: 0.08s
# ...

# %%
print(t_base)
# Out:
# {(0, 1, 1): 0.12369316876852982, (0, 1, 2): 0.12369316876852982, (0, 2, 1): 0.13152946437965907, (0, 2, 2): 0.13152946437965907, (0, 3, 1): 0.18788294228055935, (0, 3, 2): 0.18788294228055935, (0, 4, 1): 0.09899494936611665, (0, 4, 2): 0.09899494936611665, (0, 6, 1): 0.12369316876852982, (0, 6, 2): 0.12369316876852982, (0, 7, 1): 0.13152946437965907, (0, 7, 2): 0.13152946437965907, (0, 8, 1): 0.18788294228055935, (0, 8, 2): 0.18788294228055935, (0, 9, 1): 0.12369316876852982, (0, 9, 2): 0.12369316876852982, (0, 10, 1): 0.13152946437965907, (0, 10, 2): 0.13152946437965907, (0, 11, 1): 0.18788294228055935, (0, 11, 2): 0.18788294228055935, (0, 5, 1): 0.0, (0, 5, 2): 0.0, (1, 2, 1): 0.1414213562373095, (1, 2, 2): 0.1414213562373095, (1, 3, 1): 0.07071067811865475, (1, 3, 2): 0.07071067811865475, (1, 4, 1): 0.1118033988749895, (1, 4, 2): 0.1118033988749895, (1, 6, 1): 0.0, (1, 6, 2): 0.0, (1, 7, 1): 0.1414213562373095, (1, 7, 2): 0.1414213562373095, (1, 8, 1): 0.07071067811865475, (1, 8, 
# ...

# %%
active_arcs = [a for a in A if x[a].x > 0.99]

values = {}
vehicle_dist={}
vehicle_time={}
for i,j,k in active_arcs:
     print(i,j,k,"aman")
for i,j,k in active_arcs:
    if(k not in vehicle_dist):
      vehicle_dist[k] = c[i,j]     
      vehicle_time[k] = (t_base[i,j,k])*(u[j,k].x)
    else:
         vehicle_dist[k]+=c[i,j]
         vehicle_time[k]+=(t_base[i,j,k])*(u[j,k].x)

    if i!=0:
        values[i]=(j,k)
        
colors = ['magenta', 'green', 'red', 'yellow', 'cyan']
def rec(i, j,k,col):
        print(i,j,k)
        mid_x = (latitude[i] + latitude[j]) / 2
        mid_y = (longitude[i] + longitude[j]) / 2
        plt.arrow(latitude[i], longitude[i], mid_x - latitude[i], mid_y - longitude[i],
                  head_width=0.5, head_length=0.5, fc='red', ec='red')   
        plt.plot([latitude[i],latitude[j]], [longitude[i], longitude[j]], c = colors[col])
        if(j==mxCustomers+1):
             return
        rec(j,values[j][0],values[j][1],col)

# %%
# Extracting latitude and longitude values for different scatter plots
latitudes_customers = [latitude[i] for i in range(1, mxCustomers+1)]
longitudes_customers = [longitude[i] for i in range(1, mxCustomers+1)]

latitudes_charging_stations = [latitude[i] for i in range(mxCustomers+2, mxCustomers+2+mxChargingStations*num_of_copies)]
longitudes_charging_stations = [longitude[i] for i in range(mxCustomers+2, mxCustomers+2+mxChargingStations*num_of_copies)]

latitudes_battery_swapping_stations = [latitude[i] for i in range(mxCustomers+2+mxChargingStations*num_of_copies, mxCustomers+2+mxChargingStations*num_of_copies+mxBatterySwappingStations*num_of_copies)]
longitudes_battery_swapping_stations = [longitude[i] for i in range(mxCustomers+2+mxChargingStations*num_of_copies, mxCustomers+2+mxChargingStations*num_of_copies+mxBatterySwappingStations*num_of_copies)]

# Plotting
plt.scatter(latitudes_customers, longitudes_customers, c='blue')
plt.scatter(latitudes_charging_stations, longitudes_charging_stations, c='black')
plt.scatter(latitudes_battery_swapping_stations, longitudes_battery_swapping_stations, c='orange')
plt.scatter(latitude[0], longitude[0], c='r')
plt.text(latitude[0]-2, longitude[0]-2, 'Depo', fontsize=8, color='black', ha='right', va='bottom')

visited = []
for i in I:
    if(i not in visited):
      plt.annotate('$q_%d = %d$' % (i,demandWeight[i]), (latitude[i]-1, longitude[i]+1))
      visited.append(i)

count=1
print(F)
for i in F:
    if(i not in visited):
      plt.annotate('BCS: $%d$' % count, (latitude[i]-2, longitude[i]+2))
      count+=1
      visited.append(i)

count=1
for i in B:
    if(i not in visited):
      plt.annotate('BSS: $%d$' % count, (latitude[i]-3, longitude[i]+3))
      count+=1
      visited.append(i)

col=0
for i,j,k in active_arcs:
    if(i==0):
        mid_x = (latitude[i] + latitude[j]) / 2
        mid_y = (longitude[i] + longitude[j]) / 2
        plt.arrow(latitude[i], longitude[i], mid_x - latitude[i], mid_y - longitude[i],
                  head_width=0.2, head_length=0.2, fc='red', ec='red')  
        print(i,j,k)      
        rec(i,j,k,col)
        col+=1

total_charging_time=0
travelTime = 0
chargingTime = 0
for i,j,k in active_arcs:
    print(j,"amit")
    print(u[j,k].x, "aman")
    print(y[j,k].x,"aman")
    travelTime+=(t_base[i,j,k]*auxDivisor[j,k].x)
    chargingTime+=()

print(total_charging_time)
plt.title('With full charging: ')
plt.show()
# Out:
# [6, 7, 8]
# 0 2 2
# 0 2 2
# 2 7 2
# 7 10 2
# 10 5 2
# 0 11 1
# 0 11 1
# 11 8 1
# 8 3 1
# 3 6 1
# 6 1 1
# 1 4 1
# 4 5 1
# 2 amit
# 20.00000000000001 aman
# 0.0 aman
# 0.0657647321898295 time
# 11 amit
# 50.0 aman
# 0.0 aman
# 0.05368084065158838 time
# 4 amit
# 15.0 aman
# 141.5627775935468 aman
# 0.06388765649999399 time
# 7 amit
# 0.0 aman
# 0.0 aman
# 0.0 time
# 6 amit
# 30.0 aman
# 0.0 aman
# 0.0282842712474619 time
# 5 amit
# 0.0 aman
# 0.0 aman
# 0.09899494936611665 time
# 1 amit
# 30.0 aman
# 304.79573995103146 aman
# 0.0 time
# 10 amit
# 0.0 aman
# 0.0 aman
# 0.0 time
# 3 amit
# 50.0 aman
# 500.0 aman
# 0.0 time
# 5 amit
# 0.0 aman
# 0.0 aman
# 0.13152946437965907 time
# 8 amit
# 50.0 aman
# 0.0 aman
# 0.0 time
# 0
